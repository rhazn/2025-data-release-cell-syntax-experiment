# %% [markdown]
# # Raw Data Integrity Checks

# %% [markdown]
# ## Verify events are of excepted quantity and order

# %%
import sqlite3
import os
import shutil
import pandas as pd
from util import getTaskFromLocation

expectedEvents = [
    ("TASKSTART", 1),
    ("TASKCOMPLETED", 1),
    ("TASKSTART", 2),
    ("TASKCOMPLETED", 2),
    ("TASKSTART", 3),
    ("TASKCOMPLETED", 3),
    ("TASKSTART", 4),
    ("TASKCOMPLETED", 4),
    ("TASKSTART", 5),
    ("TASKCOMPLETED", 5),
    ("TASKSTART", 6),
    ("TASKCOMPLETED", 6),
    ("TASKSTART", 7),
    ("TASKCOMPLETED", 7),
    ("TASKSTART", 8),
    ("TASKCOMPLETED", 8),
    ("TASKSTART", 9),
    ("TASKCOMPLETED", 9),
]

experimentsWithUnexpectedEvents = []

# Copy the original data export so we do not modify it
if os.path.exists('./data/data_anon_after_data_integrity.db'):
    os.remove('./data/data_anon_after_data_integrity.db')
shutil.copyfile('./data/data_anon.db', './data/data_anon_after_data_integrity.db')

with sqlite3.connect('data/data_anon_after_data_integrity.db') as connection:
    # Get relevant events, aka those that we use to compute other values in utils
    df = pd.read_sql_query("SELECT * FROM events WHERE type in ('TASKSTART', 'CODEREVEALED', 'TASKCOMPLETED')", connection)
    df['task'] = df['location'].map(getTaskFromLocation)

for experimentid in df['experiment'].unique().tolist():
    print(f'❔ Checking {experimentid}')
    dfExperiment = df[(df['experiment'] == experimentid) & (df['task'] != 0)].reset_index()

    if (len(expectedEvents) != dfExperiment.shape[0]):
        print(f'🔴 Expected {len(expectedEvents)} events, experiment {experimentid} has {dfExperiment.shape[0]} events.')
        print(dfExperiment[['type', 'task', 'time']])
        experimentsWithUnexpectedEvents.append(experimentid)
        continue

    print(f'✅ Experiment {experimentid} has the expected amount of events.')

    i = 0
    for expectedEvent, task in expectedEvents:
        #print(f'\tChecking {i}: {expectedEvent} on task {task}')

        if (dfExperiment.loc[i, 'type'] != expectedEvent or task != dfExperiment.loc[i, 'task']):
            print(f'🔴 Expected {expectedEvent} and task {task}, experiment {experimentid} has {dfExperiment.loc[i, "type"]} and task {dfExperiment.loc[i, "task"]}.')
            print(dfExperiment[['type', 'task', 'time']])
            experimentsWithUnexpectedEvents.append(experimentid)
            break
        i += 1
    
    print(f'\t✅ All events for experiment {experimentid} are in the expected order.')

print(f'✅ Checked all experiments for expected amount of events and order of events.')
print(f'Found {len(experimentsWithUnexpectedEvents)} experiments with unexpected order or amount of events: {",".join(experimentsWithUnexpectedEvents)}')

with sqlite3.connect('data/data_anon_after_data_integrity.db') as connection:
    cursor = connection.cursor()
    cursor.execute(f'DELETE FROM events WHERE experiment IN ({",".join(experimentsWithUnexpectedEvents)})')
    connection.commit()

    print(f'✅ Deleted experiments with unexpected order or amount of events: {",".join(experimentsWithUnexpectedEvents)}')
# Out:
# ❔ Checking 54
# ✅ Experiment 54 has the expected amount of events.
# 	✅ All events for experiment 54 are in the expected order.
# ❔ Checking 50
# ✅ Experiment 50 has the expected amount of events.
# 	✅ All events for experiment 50 are in the expected order.
# ❔ Checking 24
# 🔴 Expected 18 events, experiment 24 has 19 events.
#              type  task       time
# 0       TASKSTART     1   747067.0
# 1       TASKSTART     1   862421.0
# 2   TASKCOMPLETED     1  1372462.0
# 3       TASKSTART     2  1373473.0
# 4   TASKCOMPLETED     2  1461485.0
# 5       TASKSTART     3  1462567.0
# 6   TASKCOMPLETED     3  1571386.0
# 7       TASKSTART     4  1572559.0
# 8   TASKCOMPLETED     4  1606628.0
# 9       TASKSTART     5  1608063.0
# 10  TASKCOMPLETED     5  1636300.0
# 11      TASKSTART     6  1637567.0
# 12  TASKCOMPLETED     6  1671772.0
# 13      TASKSTART     7  1672782.0
# 14  TASKCOMPLETED     7  1694553.0
# 15      TASKSTART     8  1695470.0
# 16  TASKCOMPLETED     8  1719916.0
# 17      TASKSTART     9  1720886.0
# 18  TASKCOMPLETED     9  1753595.0
# ❔ Checking 59
# ✅ Experiment 59 has the expected amount of events.
# 	✅ All events for experiment 59 are in the expected order.
# ❔ Checking 99
# ✅ Experiment 99 has the expected amount of events.
# 	✅ All events for experiment 99 are in the expected order.
# ❔ Checking 87
# ✅ Experiment 87 has the expected amount of events.
# 	✅ All events for experiment 87 are in the expected order.
# ❔ Checking 67
# ✅ Experiment 67 has the expected amount of events.
# 	✅ All events for experiment 67 are in the expected order.
# ❔ Checking 75
# ✅ Experiment 75 has the expected amount of events.
# 	✅ All events for experiment 75 are in the expected order.
# ❔ Checking 63
# ✅ Experiment 63 has the expected amount of events.
# 	✅ All events for experiment 63 are in the expected order.
# ❔ Checking 65
# ✅ Experiment 65 has the expected amount of events.
# 	✅ All events for experiment 65 are in the expected order.
# ❔ Checking 78
# ✅ Experiment 78 has the expected amount of events.
# 	✅ All events for experiment 78 are in the expected order.
# ❔ Checking 12
# ✅ Experiment 12 has the expected amount of events.
# 	✅ All events for experiment 12 are in the expected order.
# ❔ Checking 95
# ✅ Experiment 95 has the expected amount of events.
# 	✅ All events for experiment 95 are in the expected order.
# ❔ Checking 96
# ✅ Experiment 96 has the expected amount of events.
# 	✅ All events for experiment 96 are in the expected order.
# ❔ Checking 72
# ✅ Experiment 72 has the expected amount of events.
# 	✅ All events for experiment 72 are in the expected order.
# ❔ Checking 4
# 🔴 Expected 18 events, experiment 4 has 19 events.
#              type  task      time
# 0       TASKSTART     1  479254.0
# 1       TASKSTART     1   25623.0
# 2   TASKCOMPLETED     1   46418.0
# 3       TASKSTART     2   47863.0
# 4   TASKCOMPLETED     2   77205.0
# 5       TASKSTART     3   78225.0
# 6   TASKCOMPLETED     3  137013.0
# 7       TASKSTART     4  138237.0
# 8   TASKCOMPLETED     4  155510.0
# 9       TASKSTART     5  156703.0
# 10  TASKCOMPLETED     5  182931.0
# 11      TASKSTART     6  193598.0
# 12  TASKCOMPLETED     6  220531.0
# 13      TASKSTART     7  221733.0
# 14  TASKCOMPLETED     7  255675.0
# 15      TASKSTART     8  272614.0
# 16  TASKCOMPLETED     8  308241.0
# 17      TASKSTART     9  310477.0
# 18  TASKCOMPLETED     9  334370.0
# ❔ Checking 62
# ✅ Experiment 62 has the expected amount of events.
# 	✅ All events for experiment 62 are in the expected order.
# ❔ Checking 48
# ✅ Experiment 48 has the expected amount of events.
# 	✅ All events for experiment 48 are in the expected order.
# ❔ Checking 91
# ✅ Experiment 91 has the expected amount of events.
# 	✅ All events for experiment 91 are in the expected order.
# ❔ Checking 60
# ✅ Experiment 60 has the expected amount of events.
# 	✅ All events for experiment 60 are in the expected order.
# ❔ Checking 18
# ✅ Experiment 18 has the expected amount of events.
# 	✅ All events for experiment 18 are in the expected order.
# ❔ Checking 61
# ✅ Experiment 61 has the expected amount of events.
# 	✅ All events for experiment 61 are in the expected order.
# ❔ Checking 49
# ✅ Experiment 49 has the expected amount of events.
# 	✅ All events for experiment 49 are in the expected order.
# ❔ Checking 9
# ✅ Experiment 9 has the expected amount of events.
# 	✅ All events for experiment 9 are in the expected order.
# ❔ Checking 83
# ✅ Experiment 83 has the expected amount of events.
# 	✅ All events for experiment 83 are in the expected order.
# ❔ Checking 44
# ✅ Experiment 44 has the expected amount of events.
# 	✅ All events for experiment 44 are in the expected order.
# ❔ Checking 43
# ✅ Experiment 43 has the expected amount of events.
# 	✅ All events for experiment 43 are in the expected order.
# ❔ Checking 68
# ✅ Experiment 68 has the expected amount of events.
# 	✅ All events for experiment 68 are in the expected order.
# ❔ Checking 13
# ✅ Experiment 13 has the expected amount of events.
# 	✅ All events for experiment 13 are in the expected order.
# ❔ Checking 66
# ✅ Experiment 66 has the expected amount of events.
# 	✅ All events for experiment 66 are in the expected order.
# ❔ Checking 26
# ✅ Experiment 26 has the expected amount of events.
# 	✅ All events for experiment 26 are in the expected order.
# ❔ Checking 34
# ✅ Experiment 34 has the expected amount of events.
# 	✅ All events for experiment 34 are in the expected order.
# ❔ Checking 97
# ✅ Experiment 97 has the expected amount of events.
# 	✅ All events for experiment 97 are in the expected order.
# ❔ Checking 45
# ✅ Experiment 45 has the expected amount of events.
# 	✅ All events for experiment 45 are in the expected order.
# ❔ Checking 82
# ✅ Experiment 82 has the expected amount of events.
# 	✅ All events for experiment 82 are in the expected order.
# ❔ Checking 28
# ✅ Experiment 28 has the expected amount of events.
# 	✅ All events for experiment 28 are in the expected order.
# ❔ Checking 53
# ✅ Experiment 53 has the expected amount of events.
# 	✅ All events for experiment 53 are in the expected order.
# ❔ Checking 25
# ✅ Experiment 25 has the expected amount of events.
# 	✅ All events for experiment 25 are in the expected order.
# ❔ Checking 73
# ✅ Experiment 73 has the expected amount of events.
# 	✅ All events for experiment 73 are in the expected order.
# ❔ Checking 5
# ✅ Experiment 5 has the expected amount of events.
# 	✅ All events for experiment 5 are in the expected order.
# ❔ Checking 52
# ✅ Experiment 52 has the expected amount of events.
# 	✅ All events for experiment 52 are in the expected order.
# ❔ Checking 2
# ✅ Experiment 2 has the expected amount of events.
# 	✅ All events for experiment 2 are in the expected order.
# ❔ Checking 84
# ✅ Experiment 84 has the expected amount of events.
# 	✅ All events for experiment 84 are in the expected order.
# ❔ Checking 1
# ✅ Experiment 1 has the expected amount of events.
# 	✅ All events for experiment 1 are in the expected order.
# ❔ Checking 80
# ✅ Experiment 80 has the expected amount of events.
# 	✅ All events for experiment 80 are in the expected order.
# ❔ Checking 58
# ✅ Experiment 58 has the expected amount of events.
# 	✅ All events for experiment 58 are in the expected order.
# ❔ Checking 23
# ✅ Experiment 23 has the expected amount of events.
# 	✅ All events for experiment 23 are in the expected order.
# ❔ Checking 14
# ✅ Experiment 14 has the expected amount of events.
# 	✅ All events for experiment 14 are in the expected order.
# ❔ Checking 19
# ✅ Experiment 19 has the expected amount of events.
# 	✅ All events for experiment 19 are in the expected order.
# ❔ Checking 15
# ✅ Experiment 15 has the expected amount of events.
# 	✅ All events for experiment 15 are in the expected order.
# ❔ Checking 79
# ✅ Experiment 79 has the expected amount of events.
# 	✅ All events for experiment 79 are in the expected order.
# ❔ Checking 20
# ✅ Experiment 20 has the expected amount of events.
# 	✅ All events for experiment 20 are in the expected order.
# ❔ Checking 92
# ✅ Experiment 92 has the expected amount of events.
# 	✅ All events for experiment 92 are in the expected order.
# ❔ Checking 22
# ✅ Experiment 22 has the expected amount of events.
# 	✅ All events for experiment 22 are in the expected order.
# ❔ Checking 31
# ✅ Experiment 31 has the expected amount of events.
# 	✅ All events for experiment 31 are in the expected order.
# ❔ Checking 77
# ✅ Experiment 77 has the expected amount of events.
# 	✅ All events for experiment 77 are in the expected order.
# ❔ Checking 39
# ✅ Experiment 39 has the expected amount of events.
# 	✅ All events for experiment 39 are in the expected order.
# ❔ Checking 11
# 🔴 Expected 18 events, experiment 11 has 24 events.
#              type  task       time
# 0       TASKSTART     1  1015098.0
# 1   TASKCOMPLETED     1  1138163.0
# 2       TASKSTART     2  1139155.0
# 3       TASKSTART     1  1337874.0
# 4   TASKCOMPLETED     1  1377645.0
# 5       TASKSTART     2  1378392.0
# 6       TASKSTART     1  1391897.0
# 7   TASKCOMPLETED     1  1407474.0
# 8       TASKSTART     2  1408471.0
# 9   TASKCOMPLETED     2  1561700.0
# 10      TASKSTART     3  1562493.0
# 11  TASKCOMPLETED     3  1652459.0
# 12      TASKSTART     4  1654093.0
# 13  TASKCOMPLETED     4  1764090.0
# 14      TASKSTART     5  1764868.0
# 15  TASKCOMPLETED     5  1775218.0
# 16      TASKSTART     6  1776245.0
# 17  TASKCOMPLETED     6  1819250.0
# 18      TASKSTART     7  1820052.0
# 19  TASKCOMPLETED     7  1881602.0
# 20      TASKSTART     8  1882388.0
# 21  TASKCOMPLETED     8  1920818.0
# 22      TASKSTART     9  1921707.0
# 23  TASKCOMPLETED     9  1974969.0
# ❔ Checking 41
# ✅ Experiment 41 has the expected amount of events.
# 	✅ All events for experiment 41 are in the expected order.
# ❔ Checking 98
# ✅ Experiment 98 has the expected amount of events.
# 	✅ All events for experiment 98 are in the expected order.
# ❔ Checking 32
# ✅ Experiment 32 has the expected amount of events.
# 	✅ All events for experiment 32 are in the expected order.
# ❔ Checking 17
# ✅ Experiment 17 has the expected amount of events.
# 	✅ All events for experiment 17 are in the expected order.
# ❔ Checking 94
# ✅ Experiment 94 has the expected amount of events.
# 	✅ All events for experiment 94 are in the expected order.
# ❔ Checking 57
# ✅ Experiment 57 has the expected amount of events.
# 	✅ All events for experiment 57 are in the expected order.
# ❔ Checking 89
# ✅ Experiment 89 has the expected amount of events.
# 	✅ All events for experiment 89 are in the expected order.
# ❔ Checking 56
# ✅ Experiment 56 has the expected amount of events.
# 	✅ All events for experiment 56 are in the expected order.
# ❔ Checking 40
# 🔴 Expected 18 events, experiment 40 has 22 events.
#              type  task       time
# 0       TASKSTART     1  1588647.0
# 1   TASKCOMPLETED     1  2217967.0
# 2       TASKSTART     2  2219546.0
# 3   TASKCOMPLETED     2  2473785.0
# 4       TASKSTART     3  2475099.0
# 5   TASKCOMPLETED     3  2542529.0
# 6       TASKSTART     4  2543811.0
# 7   TASKCOMPLETED     4  2625058.0
# 8       TASKSTART     5  2626276.0
# 9   TASKCOMPLETED     5  2646106.0
# 10      TASKSTART     6  2647188.0
# 11  TASKCOMPLETED     6  2662593.0
# 12      TASKSTART     5  2666133.0
# 13  TASKCOMPLETED     5  2669210.0
# 14      TASKSTART     6  2670500.0
# 15  TASKCOMPLETED     6  2687530.0
# 16      TASKSTART     7  2688908.0
# 17  TASKCOMPLETED     7  2722890.0
# 18      TASKSTART     8  2724220.0
# 19  TASKCOMPLETED     8  2725738.0
# 20      TASKSTART     9  2726816.0
# 21  TASKCOMPLETED     9  2728906.0
# ❔ Checking 10
# ✅ Experiment 10 has the expected amount of events.
# 	✅ All events for experiment 10 are in the expected order.
# ❔ Checking 7
# ✅ Experiment 7 has the expected amount of events.
# 	✅ All events for experiment 7 are in the expected order.
# ❔ Checking 70
# ✅ Experiment 70 has the expected amount of events.
# 	✅ All events for experiment 70 are in the expected order.
# ❔ Checking 29
# ✅ Experiment 29 has the expected amount of events.
# 	✅ All events for experiment 29 are in the expected order.
# ❔ Checking 6
# ✅ Experiment 6 has the expected amount of events.
# 	✅ All events for experiment 6 are in the expected order.
# ❔ Checking 21
# ✅ Experiment 21 has the expected amount of events.
# 	✅ All events for experiment 21 are in the expected order.
# ❔ Checking 71
# ✅ Experiment 71 has the expected amount of events.
# 	✅ All events for experiment 71 are in the expected order.
# ❔ Checking 74
# ✅ Experiment 74 has the expected amount of events.
# 	✅ All events for experiment 74 are in the expected order.
# ❔ Checking 33
# ✅ Experiment 33 has the expected amount of events.
# 	✅ All events for experiment 33 are in the expected order.
# ❔ Checking 69
# ✅ Experiment 69 has the expected amount of events.
# 	✅ All events for experiment 69 are in the expected order.
# ❔ Checking 30
# 🔴 Expected 18 events, experiment 30 has 11 events.
#              type  task       time
# 0       TASKSTART     1  1356755.0
# 1   TASKCOMPLETED     1  1942750.0
# 2       TASKSTART     2  1945832.0
# 3   TASKCOMPLETED     2  2413196.0
# 4       TASKSTART     3  2414249.0
# 5   TASKCOMPLETED     3  2669320.0
# 6       TASKSTART     4  2670526.0
# 7   TASKCOMPLETED     4  2984735.0
# 8       TASKSTART     5  2985804.0
# 9   TASKCOMPLETED     5  3008018.0
# 10      TASKSTART     4  3010338.0
# ❔ Checking 3
# ✅ Experiment 3 has the expected amount of events.
# 	✅ All events for experiment 3 are in the expected order.
# ❔ Checking 90
# ✅ Experiment 90 has the expected amount of events.
# 	✅ All events for experiment 90 are in the expected order.
# ❔ Checking 93
# ✅ Experiment 93 has the expected amount of events.
# 	✅ All events for experiment 93 are in the expected order.
# ❔ Checking 36
# ✅ Experiment 36 has the expected amount of events.
# 	✅ All events for experiment 36 are in the expected order.
# ❔ Checking 64
# ✅ Experiment 64 has the expected amount of events.
# 	✅ All events for experiment 64 are in the expected order.
# ❔ Checking 27
# ✅ Experiment 27 has the expected amount of events.
# 	✅ All events for experiment 27 are in the expected order.
# ❔ Checking 0
# 🔴 Expected 18 events, experiment 0 has 62 events.
#              type  task       time
# 0       TASKSTART     1   661310.8
# 1   TASKCOMPLETED     1   829164.6
# 2       TASKSTART     2   830518.6
# 3   TASKCOMPLETED     2   870580.0
# 4       TASKSTART     3   871750.4
# ..            ...   ...        ...
# 57      TASKSTART     6  1589544.3
# 58      TASKSTART     7  1590232.8
# 59      TASKSTART     8  1590856.8
# 60      TASKSTART     9  1591688.1
# 61  TASKCOMPLETED     9  1659544.3
#
# [62 rows x 3 columns]
# ❔ Checking 55
# ✅ Experiment 55 has the expected amount of events.
# 	✅ All events for experiment 55 are in the expected order.
# ❔ Checking 42
# ✅ Experiment 42 has the expected amount of events.
# 	✅ All events for experiment 42 are in the expected order.
# ❔ Checking 51
# ✅ Experiment 51 has the expected amount of events.
# 	✅ All events for experiment 51 are in the expected order.
# ❔ Checking 35
# ✅ Experiment 35 has the expected amount of events.
# 	✅ All events for experiment 35 are in the expected order.
# ❔ Checking 88
# ✅ Experiment 88 has the expected amount of events.
# 	✅ All events for experiment 88 are in the expected order.
# ❔ Checking 16
# ✅ Experiment 16 has the expected amount of events.
# 	✅ All events for experiment 16 are in the expected order.
# ❔ Checking 76
# ✅ Experiment 76 has the expected amount of events.
# 	✅ All events for experiment 76 are in the expected order.
# ❔ Checking 8
# ✅ Experiment 8 has the expected amount of events.
# 	✅ All events for experiment 8 are in the expected order.
# ❔ Checking 86
# ✅ Experiment 86 has the expected amount of events.
# 	✅ All events for experiment 86 are in the expected order.
# ❔ Checking 37
# 🔴 Expected 18 events, experiment 37 has 13 events.
#              type  task      time
# 0       TASKSTART     1      76.0
# 1       TASKSTART     2      91.0
# 2       TASKSTART     3      68.0
# 3       TASKSTART     5      55.0
# 4   TASKCOMPLETED     5   50518.0
# 5       TASKSTART     6   52715.0
# 6   TASKCOMPLETED     6   94079.0
# 7       TASKSTART     7   95396.0
# 8   TASKCOMPLETED     7  136535.0
# 9       TASKSTART     8  137812.0
# 10  TASKCOMPLETED     8  167830.0
# 11      TASKSTART     9  168865.0
# 12  TASKCOMPLETED     9  186671.0
# ❔ Checking 38
# ✅ Experiment 38 has the expected amount of events.
# 	✅ All events for experiment 38 are in the expected order.
# ❔ Checking 47
# ✅ Experiment 47 has the expected amount of events.
# 	✅ All events for experiment 47 are in the expected order.
# ❔ Checking 46
# ✅ Experiment 46 has the expected amount of events.
# 	✅ All events for experiment 46 are in the expected order.
# ❔ Checking 85
# ✅ Experiment 85 has the expected amount of events.
# 	✅ All events for experiment 85 are in the expected order.
# ❔ Checking 81
# ✅ Experiment 81 has the expected amount of events.
# 	✅ All events for experiment 81 are in the expected order.
# ✅ Checked all experiments for expected amount of events and order of events.
# Found 7 experiments with unexpected order or amount of events: 24,4,11,40,30,0,37
# ✅ Deleted experiments with unexpected order or amount of events: 24,4,11,40,30,0,37
